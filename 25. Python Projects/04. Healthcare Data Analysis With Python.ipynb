# %% [markdown]
# <p style="text-align:right;">
#     <em>Content Copyrighted by Puneett Bhatnagr</em>
# </p>

# %% [markdown]
# # Healthcare Data Analysis With Python
# ___
#
# In this tutorial, we will use a healthcare dataset to perform some exploratory data analysis in order to master the concepts of **Python** and **Data Analysis**.
#
# **About Datset**
#
# This dataset contains around 480,000 records of patients data from the NTR Vaidya Seva scheme of the Government of Andhra Pradesh, India. NTR Vaidya Seva is the flagship healthcare scheme of the government in which lower-middle class and low-income citizens of the state of Andhra Pradesh can obtain free healthcare for many major diseases and ailments.
#
# **Acknowledgements**
#
# Original dataset can be found on the NTR Vaidya Seva's official website. The dataset has been partially anonymized on the official website. I've further anonymized it.
#
#
# **Inspiration**
#
# A useful beginner level real world dataset for exploratory data analysis!
#
# **Ownership**
#
# Dataset owned by the Government of Andhra Pradesh but released freely on official website.

# %% [markdown]
# ## Import the necessary libraries

# %%
# import requisite libraries 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("health.csv")
df.head()
# Out:
#         AGE     SEX CASTE_NAME CATEGORY_CODE CATEGORY_NAME SURGERY_CODE  \
# 0    1   56  Female         BC            M6    NEPHROLOGY         M6.5
# 1    2   37    Male         BC            M6    NEPHROLOGY         M6.5
# 2    3   50    Male         BC            M6    NEPHROLOGY         M6.5
# 3    4   45    Male         BC            M6    NEPHROLOGY         M6.5
# 4    5   54    Male         BC            M6    NEPHROLOGY         M6.5
#
#                             SURGERY        VILLAGE  MANDAL_NAME  ...  \
# 0  Maintenance Hemodialysis For Crf         Lolugu      Ponduru  ...
# 1  Maintenance Hemodialysis For Crf      Borivanka       Kaviti  ...
# 2  Maintenance Hemodialysis For Crf    Kapasakuddi       Kaviti  ...
# 3  Maintenance Hemodialysis For Crf    Telikipenta  Sarubujjili  ...
# 4  Maintenance Hemodialysis For Crf  Thandemvalasa   Srikakulam  ...
#
#   CLAIM_AMOUNT                                HOSP_NAME  HOSP_TYPE  \
# ...

# %% [markdown]
# ## Summary Of Dataset

# %%
# print summary statistics
df.describe().T
# Out:
#                  count           mean            std  min        25%  \
#               479688.0  239844.500000  138474.142300  1.0  119922.75
# AGE           479688.0      44.912264      18.961084  0.0      34.00
# PREAUTH_AMT   479688.0   30428.941698   27441.592281  5.0   12500.00
# CLAIM_AMOUNT  479688.0   27652.205861   25951.706037  2.0   12500.00
#
#                    50%        75%       max
#               239844.5  359766.25  479688.0
# AGE               47.0      59.00     107.0
# PREAUTH_AMT    25000.0   35000.00  520000.0
# CLAIM_AMOUNT   23200.0   30600.00  520000.0

# %% [markdown]
# We can see from the above summary matrix that the average age of a patience is 44 with the oldest being 107.
#
# We also notice that the minimum pre-authorised amount is around 5 and maximum is 520000 with and average of 31408.
#
# Also claim amount has an average of 28202, minimu of 2 and maximum of 520000.

# %% [markdown]
# ## Distribution Of Gender

# %%
df['SEX'].value_counts()
# Out:
# Male             260718
# Female           178947
# Male(Child)       25068
# Female(Child)     14925
# FEMALE               21
# MALE                  9
# Name: SEX, dtype: int64

# %% [markdown]
# As we can see there are duplicate values ​​in this column. Male and MALE are not two different sexes. We can substitute the column names to resolve this issue. I will also rename Male (Child) -> Boy and Female (Child) -> Girl for convenience.

# %%
mappings = {'MALE' : 'Male', 'FEMALE' : 'Female', 'Male(Child)' : 'Boy', 'Female(Child)' : 'Girl'}
# replace values using the defined mappings
df['SEX'] = df['SEX'].replace(mappings)
df['SEX'].value_counts()
# Out:
# Male      260727
# Female    178968
# Boy        25068
# Girl       14925
# Name: SEX, dtype: int64

# %%
# plot the value counts of sex 
df['SEX'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# We notice that there are more males patiences in our dataset.

# %% [markdown]
# ## Age Range And Distribution

# %%
sns.boxplot(df['AGE'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AGE'>

# %% [markdown]
# As we can see, the age ranges from **0** to **100** with some outliers going beyond 100.

# %% [markdown]
# ## For Each District Find Out The Most Common Surgery Type That Is Being Performed.

# %%
for i in df['DISTRICT_NAME'].unique():
    print("District: {}\n Disease and Count: {}\n '============'\n".format(i,df[df['DISTRICT_NAME']==i]['SURGERY'].value_counts().head(1)))
# Out:
# District: Srikakulam
#  Disease and Count: Maintenance Hemodialysis For Crf    3970
# Name: SURGERY, dtype: int64
#  '============'
#
# District: Kurnool
#  Disease and Count: Surgical Correction Of Longbone Fracture    2943
# Name: SURGERY, dtype: int64
#  '============'
#
# District: Vizianagaram
#  Disease and Count: Surgical Correction Of Longbone Fracture    2754
# Name: SURGERY, dtype: int64
#  '============'
#
# District: Guntur
#  Disease and Count: Surgical Correction Of Longbone Fracture    5259
# Name: SURGERY, dtype: int64
#  '============'
#
# District: Vishakhapatnam
#  Disease and Count: Maintenance Hemodialysis For Crf    5270
# Name: SURGERY, dtype: int64
#  '============'
#
# District: West Godavari
#  Disease and Count: Maintenance Hemodialysis For Crf    5478
# Name: SURGERY, dtype: int64
#  '============'
#
# District: Krishna
#  Disease and Count: Maintenance Hemodialysis For Crf    6026
# Name: SURGERY, dtype: int64
#  '============'
#
# ...

# %% [markdown]
# Our analysis shows that Nellore performs Maintenance Hemodialysis For Crf which has the highest surgery count.
#
# We can also notice that there are two surgeries involved in all districts, e.i. Hemodialysis and Longbone Fracture.

# %% [markdown]
# ## For Each District Find Out The Average Claim Amount.

# %%
for i in df['DISTRICT_NAME'].unique():
    print("District: {}\n Average Claim Amount: ₹{}\n '============'\n".format(i,df[df['DISTRICT_NAME']==i]['CLAIM_AMOUNT'].mean()))
# Out:
# District: Srikakulam
#  Average Claim Amount: ₹25593.712618634367
#  '============'
#
# District: Kurnool
#  Average Claim Amount: ₹28598.91853309593
#  '============'
#
# District: Vizianagaram
#  Average Claim Amount: ₹25097.78006899492
#  '============'
#
# District: Guntur
#  Average Claim Amount: ₹31048.73950729927
#  '============'
#
# District: Vishakhapatnam
#  Average Claim Amount: ₹25977.94638304871
#  '============'
#
# District: West Godavari
#  Average Claim Amount: ₹27936.70608610806
#  '============'
#
# District: Krishna
#  Average Claim Amount: ₹31015.383233247547
#  '============'
#
# District: East Godavari
#  Average Claim Amount: ₹26166.136719737173
#  '============'
#
# District: Prakasam
#  Average Claim Amount: ₹28655.81036215859
#  '============'
#
# District: Nellore
#  Average Claim Amount: ₹26105.122376744654
#  '============'
#
# District: YSR Kadapa
#  Average Claim Amount: ₹27945.216899192998
#  '============'
#
# District: Chittoor
# ...

# %% [markdown]
# ## Group Summary Statistics

# %%
df.groupby('CATEGORY_NAME').mean().sort_values(by='PREAUTH_AMT', ascending=False)
# Out:
#                                                           AGE    PREAUTH_AMT  \
# CATEGORY_NAME
# COCHLEAR IMPLANT SURGERY              64429.337838   1.581081  520000.000000
# CARDIAC AND CARDIOTHORACIC SURGERY   220433.263365  51.764553   87052.165471
# CRITICAL CARE                        225189.278328  51.014649   69927.226196
# SURGICAL GASTRO ENTEROLOGY           217841.149146  44.645103   64127.925427
# PLASTIC SURGERY                      198123.497622  27.419738   61115.505351
# NEUROSURGERY                         238563.168178  43.187689   53718.705139
# SURGICAL ONCOLOGY                    255125.222719  50.940826   45243.913335
# GASTROENTEROLOGY                     169310.423028  41.662383   37085.464601
# PEDIATRIC SURGERIES                  229981.847773   3.504840   34134.385044
# RADIATION ONCOLOGY                   242472.234006  51.835382   33656.716935
# CARDIOLOGY                           222494.427828  54.652048   33215.140211
# ...

# %% [markdown]
# Cochlear Implant Surgery seems to be the costliest surgery, costing ₹520000 on average. Prostheses costs ₹1200, the cheapest. The youngest age group also happens to be for Cochlear Implant Surgery: 1.58 years, while Neurology has an average patient age of ~56.

# %% [markdown]
# ## Summary Statistics For Each Hospital

# %%
df.groupby('HOSP_NAME').mean().sort_values(by='PREAUTH_AMT', ascending=False)
# Out:
#                                                                          AGE  \
# HOSP_NAME
# Maa Hospitals  Pvt. Ltd. Unit Of Vasavi Ent Ins...   21998.200000   0.900000
# Ent Nursing Home                                    228199.718519  24.170370
# Quality Care India Ltd Care Hospitals- Nampally     171128.609195  51.080460
# Ravindranath Ge Medical Associates Pvt Ltd. Glo...  176444.859527  52.484006
# Unimed Healthcare Pvt- Ltd Star Hospitals           199749.979339  30.871901
# ...                                                           ...        ...
# VENNELA NETHRALAYAM                                 456519.250000  52.785714
# VIJAYA HOSPITALS                                    373476.162162  45.810811
# NOBLE MULTI SPECIALITY HOSPITAL                     429420.800000  42.800000
# SPARK HOSPITALS                                      12862.000000  30.000000
# Swami super speciality Netralayam                   406029.000000  50.857143
#
# ...

# %% [markdown]
# <br>
#
# **Maa Hospitals Pvt. Ltd.** cost the highest with
# **pre-Authorised amount** of **520000**.

# %% [markdown]
# ## Most common surgery and count per age group

# %%
# Most common surgery and count per age group
for i in sorted(df['AGE'].unique()):
    print("Age Group: {}\nMost Common Surgery and Count: {}\n'============'\n".format(i,df[df['AGE']==i]['CATEGORY_NAME'].value_counts().head(1)))
# Out:
# Age Group: 0
# Most Common Surgery and Count: PEDIATRICS    15096
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 1
# Most Common Surgery and Count: PEDIATRICS    1707
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 2
# Most Common Surgery and Count: PEDIATRICS    918
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 3
# Most Common Surgery and Count: PEDIATRICS    670
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 4
# Most Common Surgery and Count: PEDIATRICS    691
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 5
# Most Common Surgery and Count: PEDIATRICS    313
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 6
# Most Common Surgery and Count: PEDIATRICS    307
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 7
# Most Common Surgery and Count: POLY TRAUMA    299
# Name: CATEGORY_NAME, dtype: int64
# '============'
#
# Age Group: 8
# ...

# %%
df['DISTRICT_NAME'].value_counts()
# Out:
# East Godavari     55398
# Guntur            50416
# Krishna           41964
# West Godavari     40995
# Nellore           39836
# Chittoor          36790
# Vishakhapatnam    36481
# Prakasam          34819
# Kurnool           32013
# YSR Kadapa        29244
# Anantapur         28854
# Srikakulam        27079
# Vizianagaram      25799
# Name: DISTRICT_NAME, dtype: int64

# %% [markdown]
# <br>
#
# ## Time Series Analysis

# %%
from datetime import datetime

df['SURGERY_DATE']=pd.to_datetime(df['SURGERY_DATE'])

# %%
df.set_index('SURGERY_DATE', inplace=True)

# %%
df.head()
# Out:
#                    AGE     SEX CASTE_NAME CATEGORY_CODE CATEGORY_NAME  \
# SURGERY_DATE
# 2013-06-08      1   56  Female         BC            M6    NEPHROLOGY
# 2013-08-08      2   37    Male         BC            M6    NEPHROLOGY
# 2013-08-15      3   50    Male         BC            M6    NEPHROLOGY
# 2013-08-24      4   45    Male         BC            M6    NEPHROLOGY
# 2013-08-31      5   54    Male         BC            M6    NEPHROLOGY
#
#              SURGERY_CODE                           SURGERY        VILLAGE  \
# SURGERY_DATE
# 2013-06-08           M6.5  Maintenance Hemodialysis For Crf         Lolugu
# 2013-08-08           M6.5  Maintenance Hemodialysis For Crf      Borivanka
# 2013-08-15           M6.5  Maintenance Hemodialysis For Crf    Kapasakuddi
# 2013-08-24           M6.5  Maintenance Hemodialysis For Crf    Telikipenta
# 2013-08-31           M6.5  Maintenance Hemodialysis For Crf  Thandemvalasa
#
# ...

# %% [markdown]
# <br>
#
# ## Pre-Authorised Amount Over-time

# %% [markdown]
# We will use the average of the last 12 data points to check the trend. We will use a technique called *rolling average*.
#
# A simple [***rolling average***](https://www.portent.com/blog/analytics/rolling-averages-math-moron.htm) (also called a moving average) is the unweighted mean of the last n values.

# %%
preauthoried = df[['PREAUTH_AMT']]
preauthoried.rolling(12).mean().plot(figsize=(20,10), linewidth=2, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %% [markdown]
# The highest pre-authorised amounts are seen in the month of **July 2015** and early **2016**.
#
# We can also notice that there has been a lot of clustered pre-authorised amounts between **25000** and **100000** in **January 2016** and **July 2017**.

# %% [markdown]
# ## Claim Amount Over-time

# %%
claim = df[['CLAIM_AMOUNT']]
claim.rolling(12).mean().plot(figsize=(20,10), linewidth=2, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %% [markdown]
# We have a similar account as the *Pre-Authorised Amount Over-time*

# %% [markdown]
# ## Patiences' Age Overtime

# %%
age = df[['AGE']]
age.rolling(12).mean().plot(figsize=(20,10), linewidth=2, fontsize=20,color='red')
plt.xlabel('Year', fontsize=20);

# %% [markdown]
# Around **2014**, there were few old age patiences as compare to between **January, 2016** and **July 2017** where number of both young and old patiences increased significantly.

# %% [markdown]
# ___
#
# <p style="text-align:right;">
#     <em>Content Copyrighted by Puneett Bhatnagr</em>
# </p>
